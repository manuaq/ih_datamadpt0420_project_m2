# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
diamonds_df = pd.read_csv('/Users/manuelaquino/Bootcamp/ih_datamadpt1120_project_m2/data/diamonds_train.csv', low_memory=False)
diamonds_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1       0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2       0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3       0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4       1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  10070  7.10  7.04  4.43
# 40451   2.02       Good     F     SI2   57.1   60.0  12615  8.31  8.25  4.73
# 40452   1.01      Ideal     H     SI1   62.7   56.0   5457  6.37  6.42  4.01
# 40453   0.33      Ideal     J     VS1   61.9   54.3    456  4.45  4.47  2.76
# 40454   1.24      Ideal     I     SI1   62.0   58.0   6232  6.83  6.88  4.25
#
# [40455 rows x 10 columns]

# %% [markdown]
# ## Challenge 1: Exploratory Data Visualization Charts and Summary Statistics
#
# The goal of this challenge is to build an **exploratory data analysis report** in order to gain initial insight on our diamonds dataset. Your notebook must include:<br>
#
# - Summary statistics including descriptive statistics (max, min, mean, standard deviation, percentiles, correlations, etc.) and data types (integer, float, boolean, string, etc.).<br>
# - Data visualizations charts in order to capture a large amount of data all at once in a clear and concise manner (Box Plots, Histograms, Bar Plots, Scatter Plots, Correlation Matrix, etc.).

# %%
diamonds_df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  40455.000000  40455.000000  40455.000000  40455.000000  40455.000000
# mean       0.797706     61.752841     57.446133   3928.444469      5.729392
# std        0.475544      1.431725      2.233535   3992.416147      1.124453
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    945.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2397.000000      5.690000
# 75%        1.040000     62.500000     59.000000   5331.000000      6.540000
# max        4.500000     79.000000     95.000000  18823.000000     10.230000
#
#                   y             z
# count  40455.000000  40455.000000
# mean       5.732819      3.537154
# std        1.146650      0.697062
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.520000
# 75%        6.540000      4.035000
# ...

# %%
diamonds_df.describe(include='all')
# Out:
#                carat    cut  color clarity         depth         table  \
# count   40455.000000  40455  40455   40455  40455.000000  40455.000000
# unique           NaN      5      7       8           NaN           NaN
# top              NaN  Ideal      G     SI1           NaN           NaN
# freq             NaN  16220   8455    9749           NaN           NaN
# mean        0.797706    NaN    NaN     NaN     61.752841     57.446133
# std         0.475544    NaN    NaN     NaN      1.431725      2.233535
# min         0.200000    NaN    NaN     NaN     43.000000     43.000000
# 25%         0.400000    NaN    NaN     NaN     61.000000     56.000000
# 50%         0.700000    NaN    NaN     NaN     61.800000     57.000000
# 75%         1.040000    NaN    NaN     NaN     62.500000     59.000000
# max         4.500000    NaN    NaN     NaN     79.000000     95.000000
#
#                price             x             y             z
# ...

# %%
diamonds_df.corr()
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.026528  0.183392  0.921935  0.975688  0.951667  0.967570
# depth  0.026528  1.000000 -0.293114 -0.014864 -0.026348 -0.030966  0.094655
# table  0.183392 -0.293114  1.000000  0.130111  0.196059  0.184673  0.155189
# price  0.921935 -0.014864  0.130111  1.000000  0.885848  0.866163  0.874500
# x      0.975688 -0.026348  0.196059  0.885848  1.000000  0.973712  0.984876
# y      0.951667 -0.030966  0.184673  0.866163  0.973712  1.000000  0.964828
# z      0.967570  0.094655  0.155189  0.874500  0.984876  0.964828  1.000000

# %%
diamonds_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    40455 non-null  float64
#  1   cut      40455 non-null  object
#  2   color    40455 non-null  object
#  3   clarity  40455 non-null  object
#  4   depth    40455 non-null  float64
#  5   table    40455 non-null  float64
#  6   price    40455 non-null  int64
#  7   x        40455 non-null  float64
#  8   y        40455 non-null  float64
#  9   z        40455 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.1+ MB

# %%
diamonds_df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Fair', 'Good', 'Ideal'], dtype=object)

# %%
diamond_cut_ordered_list = ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']
print(len(diamond_cut_ordered_list))
print(diamonds_df['cut'].unique())
print(len(diamonds_df['cut'].unique()))
print('diamond_cut_ordered_list', diamond_cut_ordered_list)
# Out:
# 5
# ['Premium' 'Very Good' 'Fair' 'Good' 'Ideal']
# 5
# diamond_cut_ordered_list ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))
sns.set_theme(style="darkgrid")
ax = sns.countplot(x=diamonds_df['cut'], data=diamonds_df, order=diamond_cut_ordered_list, palette="Blues")
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, horizontalalignment='center', fontweight='light',fontsize='medium')
plt.xlabel("From left: Ideal (Best Cut) to Fair Cut", fontweight='bold', size=13)
plt.ylabel("Diamond Count", fontweight='bold', size=13)
plt.title("Available Diamonds by Cut", size=16, fontweight='bold')

plt.show()

# %%
diamonds_df['color'].unique()
# Out:
# array(['J', 'H', 'G', 'D', 'F', 'E', 'I'], dtype=object)

# %%
diamond_color_ordered_list = ['D', 'E', 'F', 'G', 'H', 'I', 'J']
print(len(diamond_color_ordered_list))
print(diamonds_df['color'].unique())
print(len(diamonds_df['color'].unique()))
print('diamond_color_ordered_list', diamond_color_ordered_list)
# Out:
# 7
# ['J' 'H' 'G' 'D' 'F' 'E' 'I']
# 7
# diamond_color_ordered_list ['D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))
sns.set_theme(style="darkgrid")
ax = sns.countplot(x=diamonds_df['color'], data=diamonds_df, order=diamond_color_ordered_list, palette="Blues")
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, horizontalalignment='center', fontweight='light',fontsize='medium')
plt.xlabel("From left: D (Best Colorless) to J (Near Colorless)", fontweight='bold', size=13)
plt.ylabel("Diamond Count", fontweight='bold', size=13)
plt.title("Available Diamonds by Color", size=16, fontweight='bold')

plt.show()

# %%
sns.catplot(x="color", y="price", kind="boxen", data=diamonds_df.sort_values("color"))
plt.gcf().set_size_inches(12, 5)
plt.xlabel("Color Grades: Best from left -> D (Colorless) to J (Near Colorless)", fontweight='bold', size=13)
plt.ylabel("Diamond Prices", fontweight='bold', size=13)
plt.title("Diamond Prices by Color", size=16, fontweight='bold')
plt.show();

# %%
sns.boxplot(x="color", y="price", data=diamonds_df.sort_values("color"))
plt.gcf().set_size_inches(12, 5)
plt.xlabel("Color Grades: Best from left -> D (Colorless) to J (Near Colorless)", fontweight='bold', size=13)
plt.ylabel("Diamond Prices", fontweight='bold', size=13)
plt.title("Diamond Prices by Color", size=16, fontweight='bold')
plt.show();

# %%
diamonds_df['clarity'].unique()
# Out:
# array(['VS2', 'VS1', 'SI1', 'SI2', 'IF', 'VVS1', 'VVS2', 'I1'],
#       dtype=object)

# %%
diamond_clarity_ordered_list = ['IF', 'VVS1', 'VVS2', 'VS1', 'VS2', 'SI1', 'SI2', 'I1' ]
print(len(diamond_clarity_ordered_list))
print(diamonds_df['clarity'].unique())
print(len(diamonds_df['clarity'].unique()))
# Out:
# 8
# ['VS2' 'VS1' 'SI1' 'SI2' 'IF' 'VVS1' 'VVS2' 'I1']
# 8

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))
sns.set_theme(style="whitegrid")
ax = sns.countplot(x=diamonds_df['clarity'], data=diamonds_df, order=diamond_clarity_ordered_list, palette="Blues")
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, horizontalalignment='center', fontweight='light',fontsize='medium')
plt.xlabel("From left: IF (Best Clarity) to I1 (Less Clarity)", fontweight='bold', size=13)
plt.ylabel("Diamond Count", fontweight='bold', size=13)
plt.title("Available Diamonds by Clarity", size=16, fontweight='bold')

plt.show()

# %%
sns.catplot(x="clarity", y="price", kind="boxen", data=diamonds_df, order=diamond_clarity_ordered_list)
plt.gcf().set_size_inches(12, 5)
plt.xlabel("From left: IF (Best Clarity) to I1 (Less Clarity)", fontweight='bold', size=13)
plt.ylabel("Diamond Prices", fontweight='bold', size=13)
plt.title("Diamond Prices by Clarity", size=16, fontweight='bold')
plt.show();

# %%
sns.boxplot(x="clarity", y="price", data=diamonds_df, order=diamond_clarity_ordered_list)
plt.gcf().set_size_inches(12, 5)
plt.xlabel("From left: IF (Best Clarity) to I1 (Less Clarity)", fontweight='bold', size=13)
plt.ylabel("Diamond Prices", fontweight='bold', size=13)
plt.title("Diamond Prices by Clarity", size=16, fontweight='bold')
plt.show();

# %%
pd.plotting.scatter_matrix(diamonds_df, figsize=(16,12), alpha=0.3)

plt.show()

# %%
plt.figure(figsize=[12,12])

# First subplot showing the diamond carat weight distribution
plt.subplot(221)
plt.hist(diamonds_df['carat'],bins=20,color='b')
plt.xlabel('Carat Weight')
plt.ylabel('Frequency')
plt.title('Distribution of Diamond Carat Weight')

# Second subplot showing the diamond depth distribution
plt.subplot(222)
plt.hist(diamonds_df['depth'],bins=20,color='r')
plt.xlabel('Diamond Depth (%)')
plt.ylabel('Frequency')
plt.title('Distribution of Diamond Depth')

# Third subplot showing the diamond price distribution
plt.subplot(223)
plt.hist(diamonds_df['price'],bins=10,color='g')
plt.xlabel('Price in USD')
plt.ylabel('Frequency')
plt.title('Distribution of Diamond Price')

plt.show()

# %%
sns.catplot( y='carat', kind='box', data=diamonds_df, height=5, palette='colorblind')
plt.gcf().set_size_inches(6, 5);

# %%
plt.figure(figsize=(12, 12))
correlation = diamonds_df.select_dtypes(include = ['float64', 'int64']).corr()
sns.heatmap(correlation, vmax=1, annot=True,square=True)
plt.show()

# %%
diamonds_df['cut_num'] = diamonds_df['cut'].apply(lambda x: 1 if x=='Fair' else(2 if x=='Good' 
                                           else(3 if x=='Very Good' 
                                           else(4 if x=='Premium' else 5))))

diamonds_df['color_num'] = diamonds_df['color'].apply(lambda x: 1 if x=='J' else(2 if x=='I'
                                          else(3 if x=='H'
                                          else(4 if x=='G'
                                          else(5 if x=='F'
                                          else(6 if x=='E' else 7))))))

diamonds_df['clarity_num'] = diamonds_df['clarity'].apply(lambda x: 1 if x=='I1' else(2 if x=='SI2'
                                          else(3 if x=='SI1'
                                          else(4 if x=='VS2'
                                          else(5 if x=='VS1'
                                          else(6 if x=='WS2'
                                          else 7 if x=='WS1' else 8))))))

diamonds_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1       0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2       0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3       0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4       1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  10070  7.10  7.04  4.43
# 40451   2.02       Good     F     SI2   57.1   60.0  12615  8.31  8.25  4.73
# 40452   1.01      Ideal     H     SI1   62.7   56.0   5457  6.37  6.42  4.01
# 40453   0.33      Ideal     J     VS1   61.9   54.3    456  4.45  4.47  2.76
# 40454   1.24      Ideal     I     SI1   62.0   58.0   6232  6.83  6.88  4.25
#
#        cut_num  color_num  clarity_num
# ...

# %%
plt.figure(figsize=(12, 12))
correlation = diamonds_df.select_dtypes(include = ['float64', 'int64']).corr()
sns.heatmap(correlation, vmax=1, annot=True,square=True)
plt.show()

# %% [markdown]
# #### Some shortcuts to sources of information:
# ##### https://datavizpyr.com/change-axis-labels-set-title-and-figure-size-to-plots-with-seaborn/
# ##### https://seaborn.pydata.org/tutorial/color_palettes.html
# ##### https://pbpython.com/categorical-encoding.html
# ##### https://www.marsja.se/pandas-scatter-matrix-pair-plot/
